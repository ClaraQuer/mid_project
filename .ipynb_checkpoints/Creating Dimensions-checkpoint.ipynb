# %%
import pandas as pd
import numpy as np
import country_converter as coco
import re
import pandas_profiling as pp
import pymysql
from sqlalchemy import create_engine
import getpass
import math
import seaborn as sns
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from sklearn.metrics import r2_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 2000)

# %%
password = getpass.getpass()
# Out:
# ········

# %% [markdown]
# ### Importing data from SQL

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/p5'
engine = create_engine(connection_string)

# %%
query = '''SELECT i.continent, i.region, p.iso3, i.country_name, i.indicator_id, i.value, p.democ, p.autoc, p.polity, id.indicator_name, d.dimension
FROM in17 i
    LEFT JOIN p5_score p
        ON i.country_name = p.country
    JOIN indicator id
        USING (indicator_id)
    LEFT JOIN dimensions d
        USING (indicator_id)
GROUP BY country_name, indicator_id
ORDER BY country_name'''

data = pd.read_sql_query(query, engine)
data = data[~data['polity'].isin([-77, -88, -99])]
data.head()
# Out:
#   continent         region iso3 country_name  indicator_id   value  democ  \
# 0      Asia  Southern Asia  AFG  Afghanistan             1     0.0    1.0
# 1      Asia  Southern Asia  AFG  Afghanistan             2     1.0    1.0
# 2      Asia  Southern Asia  AFG  Afghanistan             3     0.0    1.0
# 3      Asia  Southern Asia  AFG  Afghanistan         21806  2621.1    1.0
# 4      Asia  Southern Asia  AFG  Afghanistan         23806    25.1    1.0
#
#    autoc  polity                                     indicator_name  \
# 0    2.0    -1.0             European Union Membership (True/False)
# 1    2.0    -1.0             United Nations Membership (True/False)
# 2    2.0    -1.0                       OECD Membership (True/False)
# 3    2.0    -1.0          Refugees by country of origin (thousands)
# 4    2.0    -1.0  Population with at least some secondary educat...
#
#                      dimension
# 0  International Organisations
# 1  International Organisations
# 2  International Organisations
# 3               Human Security
# 4                    Education

# %% [markdown]
# ### Creating Dimensions and dealing with NaNs

# %%
data['dimension'].fillna('Other', inplace = True)

# %%
data['dimension'].unique()
# Out:
# array(['International Organisations', 'Human Security', 'Education',
#        'Environmental sustainability', 'Gender', 'Poverty',
#        'Work, employment and vulnerability', 'Other', 'Demography',
#        'Mobility and communication', 'Trade and financial flows',
#        'Health', 'Income/composition of resources', 'Inequality',
#        'Socio-economic sustainability'], dtype=object)

# %%
dimensions = data.pivot_table(index = ['dimension', 'indicator_id'], aggfunc = 'count').reset_index()
dimensions
# Out:
#                               dimension  indicator_id  autoc  continent  \
# 0                            Demography         44206    162        192
# 1                            Demography         45106    162        192
# 2                            Demography         47906    162        182
# 3                            Demography         49006    162        182
# 4                            Demography         63106    162        182
# 5                            Demography        121206    162        182
# 6                            Demography        122006    162        182
# 7                            Demography        132706    162        182
# 8                            Demography        132806    162        182
# 9                             Education         23806    148        164
# 10                            Education         23906    147        163
# 11                            Education         24006    147        163
# 12                            Education         24106    154        168
# 13                            Education         24206    154        168
# 14                            Education         45806     96        116
# 15                            Education         46106    140        163
# 16                            Education         46206    139        166
# 17                            Education         63206    150        176
# 18                            Education         63306    141        165
# 19                            Education         63406    135        151
# 20                            Education         69706    161        189
# 21                            Education        101406    122        133
# 22                            Education        103006    160        186
# 23                            Education        123306    155        178
# 24                            Education        123406    155        178
# 25                            Education        133006    138        164
# 26                            Education        149206    120        139
# 27                            Education        176606     71         84
# 28                            Education        176806     64         67
# 29                            Education        176906     64         67
# 30                            Education        177006     64         67
# 31                            Education        177706    142        167
# 32         Environmental sustainability         27706    162        190
# 33         Environmental sustainability         97106     95        104
# 34         Environmental sustainability        100806    162        190
# 35         Environmental sustainability        174306    131        135
# 36         Environmental sustainability        174406    158        184
# 37         Environmental sustainability        181606    162        192
# 38                               Gender         31706    162        190
# 39                               Gender         36806    162        182
# 40                               Gender         68606    147        158
# 41                               Gender        123506    160        175
# 42                               Gender        123606    160        175
# 43                               Gender        128106    154        175
# 44                               Gender        167406     94        107
# 45                               Gender        167506     46         56
# 46                               Gender        175006     73         81
# 47                               Gender        175206    120        142
# 48                               Gender        175506    135        149
# 49                               Gender        175606    110        123
# 50                               Gender        175706    149        153
# 51                               Gender        175906     99        106
# 52                               Gender        181206    141        161
# 53                               Gender        181406    110        123
# 54                               Health         57806    158        177
# 55                               Health         57906    158        177
# 56                               Health         58006    126        130
# 57                               Health         69206    162        188
# 58                               Health         98306    116        129
# 59                       Human Security         21806    162        188
# 60                       Human Security         61006    153        179
# 61                       Human Security        128306    158        186
# 62                       Human Security        181106    148        167
# 63      Income/composition of resources         65606    154        167
# 64      Income/composition of resources        127606    149        168
# 65      Income/composition of resources        136706    156        183
# 66      Income/composition of resources        141706    160        188
# 67      Income/composition of resources        143306    156        183
# 68                           Inequality         67106    140        152
# 69                           Inequality        101606    150        167
# 70                           Inequality        101706    141        154
# 71                           Inequality        101806    162        182
# 72                           Inequality        135106    140        152
# 73                           Inequality        135206    140        152
# 74          International Organisations             1    162        192
# 75          International Organisations             2    162        192
# 76          International Organisations             3    162        192
# 77           Mobility and communication         46006    162        190
# 78           Mobility and communication        110806    162        182
# 79           Mobility and communication        111106    153        182
# 80           Mobility and communication        147206    124        139
# 81           Mobility and communication        178106     82         87
# 82                                Other         43606    161        187
# 83                                Other         57206    162        190
# 84                                Other         57506    162        190
# 85                                Other         64306    162        190
# 86                                Other         64406    162        190
# 87                                Other         71406    150        166
# 88                                Other         71506    162        182
# 89                                Other         71606    141        154
# 90                                Other         73506    140        150
# 91                                Other         89006    162        179
# 92                                Other        103206    162        188
# 93                                Other        103606    160        188
# 94                                Other        103706    160        186
# 95                                Other        120606    162        182
# 96                                Other        121106    162        182
# 97                                Other        135006    140        150
# 98                                Other        136906    150        161
# 99                                Other        137006    150        161
# 100                               Other        137506    160        186
# 101                               Other        137906    150        161
# 102                               Other        138806    140        150
# 103                               Other        146206    160        186
# 104                               Other        149406    161        185
# 105                               Other        163906    162        190
# 106                               Other        164206    159        184
# 107                               Other        169706    162        177
# 108                               Other        169806    162        177
# 109                               Other        175106    162        177
# 110                               Other        177106    161        190
# 111                               Other        177206    162        190
# 112                               Other        181806    158        185
# 113                               Other        182106     94         97
# 114                               Other        182206    162        191
# 115                             Poverty         38406     95        102
# 116                             Poverty         38506     95        102
# 117                             Poverty         38606     95        102
# 118                             Poverty         39006     89         93
# 119                             Poverty        101006     95        102
# 120                             Poverty        102006     95        102
# 121                             Poverty        117806     95        102
# 122                             Poverty        117906     95        102
# 123                             Poverty        118006     95        102
# 124                             Poverty        142506     95        102
# 125                             Poverty        153706    125        132
# 126                             Poverty        167106     82         86
# 127                             Poverty        183406     95        102
# 128       Socio-economic sustainability         52306    120        126
# 129       Socio-economic sustainability        164406    143        151
# 130       Socio-economic sustainability        170106    117        123
# 131       Socio-economic sustainability        174206    105        116
# 132       Socio-economic sustainability        178306    158        171
# 133       Socio-economic sustainability        179406    130        140
# 134       Socio-economic sustainability        179706    113        116
# 135       Socio-economic sustainability        181706    161        188
# 136       Socio-economic sustainability        183206    128        131
# 137           Trade and financial flows         52606    150        173
# 138           Trade and financial flows         53506    159        185
# 139           Trade and financial flows         99106    118        139
# 140           Trade and financial flows        111306    147        171
# 141           Trade and financial flows        133206    158        181
# 142  Work, employment and vulnerability         43006    162        177
# 143  Work, employment and vulnerability         48706    162        177
# 144  Work, employment and vulnerability         48806    162        177
# 145  Work, employment and vulnerability        110906    162        177
# 146  Work, employment and vulnerability        123806    149        173
# 147  Work, employment and vulnerability        140606    162        177
# 148  Work, employment and vulnerability        147906    105        113
# 149  Work, employment and vulnerability        148206    162        177
# 150  Work, employment and vulnerability        148306    162        177
# 151  Work, employment and vulnerability        150606    162        177
# 152  Work, employment and vulnerability        150706    162        177
# 153  Work, employment and vulnerability        181306     67         72
#
#      country_name  democ  indicator_name  iso3  polity  region  value
# 0             192    162             192   162     162     192    192
# 1             192    162             192   162     162     192    192
# 2             182    162             182   162     162     182    182
# 3             182    162             182   162     162     182    182
# 4             182    162             182   162     162     182    182
# 5             182    162             182   162     162     182    182
# 6             182    162             182   162     162     182    182
# 7             182    162             182   162     162     182    182
# 8             182    162             182   162     162     182    182
# 9             164    148             164   148     148     164    164
# 10            163    147             163   147     147     163    163
# 11            163    147             163   147     147     163    163
# 12            168    154             168   154     154     168    168
# 13            168    154             168   154     154     168    168
# 14            116     96             116    96      96     116    116
# 15            163    140             163   140     140     163    163
# 16            166    139             166   139     139     166    166
# 17            176    150             176   150     150     176    176
# 18            165    141             165   141     141     165    165
# 19            151    135             151   135     135     151    151
# 20            189    161             189   161     161     189    189
# 21            133    122             133   122     122     133    133
# 22            186    160             186   160     160     186    186
# 23            178    155             178   155     155     178    178
# 24            178    155             178   155     155     178    178
# 25            164    138             164   138     138     164    164
# 26            139    120             139   120     120     139    139
# 27             84     71              84    71      71      84     84
# 28             67     64              67    64      64      67     67
# 29             67     64              67    64      64      67     67
# 30             67     64              67    64      64      67     67
# 31            167    142             167   142     142     167    167
# 32            190    162             190   162     162     190    190
# 33            104     95             104    95      95     104    104
# 34            190    162             190   162     162     190    190
# 35            135    131             135   131     131     135    135
# 36            184    158             184   158     158     184    184
# 37            192    162             192   162     162     192    192
# 38            190    162             190   162     162     190    190
# 39            182    162             182   162     162     182    182
# 40            158    147             158   147     147     158    158
# 41            175    160             175   160     160     175    175
# 42            175    160             175   160     160     175    175
# 43            175    154             175   154     154     175    175
# 44            107     94             107    94      94     107    107
# 45             56     46              56    46      46      56     56
# 46             81     73              81    73      73      81     81
# 47            142    120             142   120     120     142    142
# 48            149    135             149   135     135     149    149
# 49            123    110             123   110     110     123    123
# 50            153    149             153   149     149     153    153
# 51            106     99             106    99      99     106    106
# 52            161    141             161   141     141     161    161
# 53            123    110             123   110     110     123    123
# 54            177    158             177   158     158     177    177
# 55            177    158             177   158     158     177    177
# 56            130    126             130   126     126     130    130
# 57            188    162             188   162     162     188    188
# 58            129    116             129   116     116     129    129
# 59            188    162             188   162     162     188    188
# 60            179    153             179   153     153     179    179
# 61            186    158             186   158     158     186    186
# 62            167    148             167   148     148     167    167
# 63            167    154             167   154     154     167    167
# 64            168    149             168   149     149     168    168
# 65            183    156             183   156     156     183    183
# 66            188    160             188   160     160     188    188
# 67            183    156             183   156     156     183    183
# 68            152    140             152   140     140     152    152
# 69            167    150             167   150     150     167    167
# 70            154    141             154   141     141     154    154
# 71            182    162             182   162     162     182    182
# 72            152    140             152   140     140     152    152
# 73            152    140             152   140     140     152    152
# 74            192    162             192   162     162     192    192
# 75            192    162             192   162     162     192    192
# 76            192    162             192   162     162     192    192
# 77            190    162             190   162     162     190    190
# 78            182    162             182   162     162     182    182
# 79            182    153             182   153     153     182    182
# 80            139    124             139   124     124     139    139
# 81             87     82              87    82      82      87     87
# 82            187    161             187   161     161     187    187
# 83            190    162             190   162     162     190    190
# 84            190    162             190   162     162     190    190
# 85            190    162             190   162     162     190    190
# 86            190    162             190   162     162     190    190
# 87            166    150             166   150     150     166    166
# 88            182    162             182   162     162     182    182
# 89            154    141             154   141     141     154    154
# 90            150    140             150   140     140     150    150
# 91            179    162             179   162     162     179    179
# 92            188    162             188   162     162     188    188
# 93            188    160             188   160     160     188    188
# 94            186    160             186   160     160     186    186
# 95            182    162             182   162     162     182    182
# 96            182    162             182   162     162     182    182
# 97            150    140             150   140     140     150    150
# 98            161    150             161   150     150     161    161
# 99            161    150             161   150     150     161    161
# 100           186    160             186   160     160     186    186
# 101           161    150             161   150     150     161    161
# 102           150    140             150   140     140     150    150
# 103           186    160             186   160     160     186    186
# 104           185    161             185   161     161     185    185
# 105           190    162             190   162     162     190    190
# 106           184    159             184   159     159     184    184
# 107           177    162             177   162     162     177    177
# 108           177    162             177   162     162     177    177
# 109           177    162             177   162     162     177    177
# 110           190    161             190   161     161     190    190
# 111           190    162             190   162     162     190    190
# 112           185    158             185   158     158     185    185
# 113            97     94              97    94      94      97     97
# 114           191    162             191   162     162     191    191
# 115           102     95             102    95      95     102    102
# 116           102     95             102    95      95     102    102
# 117           102     95             102    95      95     102    102
# 118            93     89              93    89      89      93     93
# 119           102     95             102    95      95     102    102
# 120           102     95             102    95      95     102    102
# 121           102     95             102    95      95     102    102
# 122           102     95             102    95      95     102    102
# 123           102     95             102    95      95     102    102
# 124           102     95             102    95      95     102    102
# 125           132    125             132   125     125     132    132
# 126            86     82              86    82      82      86     86
# 127           102     95             102    95      95     102    102
# 128           126    120             126   120     120     126    126
# 129           151    143             151   143     143     151    151
# 130           123    117             123   117     117     123    123
# 131           116    105             116   105     105     116    116
# 132           171    158             171   158     158     171    171
# 133           140    130             140   130     130     140    140
# 134           116    113             116   113     113     116    116
# 135           188    161             188   161     161     188    188
# 136           131    128             131   128     128     131    131
# 137           173    150             173   150     150     173    173
# 138           185    159             185   159     159     185    185
# 139           139    118             139   118     118     139    139
# 140           171    147             171   147     147     171    171
# 141           181    158             181   158     158     181    181
# 142           177    162             177   162     162     177    177
# 143           177    162             177   162     162     177    177
# 144           177    162             177   162     162     177    177
# 145           177    162             177   162     162     177    177
# 146           173    149             173   149     149     173    173
# 147           177    162             177   162     162     177    177
# 148           113    105             113   105     105     113    113
# 149           177    162             177   162     162     177    177
# 150           177    162             177   162     162     177    177
# 151           177    162             177   162     162     177    177
# 152           177    162             177   162     162     177    177
# 153            72     67              72    67      67      72     72

# %%
demography_lst = []
education_lst = []
environment_lst = []
gender_lst = []
health_lst = []
security_lst = []
income_lst = []
inequality_lst = []
international_organisations_lst = []
communication_lst = []
other_lst = []
poverty_lst = []
socioeconomic_lst = []
financial_lst = []
work_lst = []

for i in range (len(dimensions['dimension'])):
    if dimensions['dimension'][i] == 'International Organisations':
        international_organisations_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Demography':
        demography_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Human Security':
        security_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Education':
        education_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Environmental sustainability':
        environment_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Gender':
        gender_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Poverty':
        poverty_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Work, employment and vulnerability':
        work_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Mobility and communication':
        communication_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Trade and financial flows':
        financial_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Socio-economic sustainability':
        socioeconomic_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Health':
        health_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Income/composition of resources':
        income_lst.append(int(dimensions['indicator_id'][i]))
    elif dimensions['dimension'][i] == 'Inequality':
        inequality_lst.append(int(dimensions['indicator_id'][i]))
    else:
        other_lst.append(int(dimensions['indicator_id'][i]))

# %%
demography_df = data[data['indicator_id'].isin(demography_lst)]
education_df = data[data['indicator_id'].isin(education_lst)]
environment_df = data[data['indicator_id'].isin(environment_lst)]
gender_df = data[data['indicator_id'].isin(gender_lst)]
health_df = data[data['indicator_id'].isin(health_lst)]
security_df = data[data['indicator_id'].isin(security_lst)]
income_df = data[data['indicator_id'].isin(income_lst)]
inequality_df = data[data['indicator_id'].isin(inequality_lst)]
int_org_df = data[data['indicator_id'].isin(international_organisations_lst)]
communication_df = data[data['indicator_id'].isin(communication_lst)]
other_df = data[data['indicator_id'].isin(other_lst)]
poverty_df = data[data['indicator_id'].isin(poverty_lst)]
socioeconomic_df = data[data['indicator_id'].isin(socioeconomic_lst)]
financial_df = data[data['indicator_id'].isin(financial_lst)]
work_df = data[data['indicator_id'].isin(work_lst)]

# %% [markdown]
# ## Demography

# %%
demography = demography_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

# %%
dem_corr = demography.corr()
sns.heatmap(dem_corr, annot=True)
plt.rcParams["figure.figsize"] = (5,5)
plt.show()

## drop autoc, democ, 132806,

# %%
demography.drop([132806, 44206, 47906, 63106], axis = 1, inplace = True)

# %%
dem_corr = demography.corr()
sns.heatmap(dem_corr, annot=True)
plt.rcParams["figure.figsize"] = (8, 8)
plt.show()

# %%
dem_lst = demography.columns.to_list()
dem_num = [num for num in dem_lst if isinstance(num, (int,float))]
dem_num
# Out:
# [45106, 49006, 121206, 122006, 132706]

# %%
dem_df = data[data['indicator_id'].isin(dem_num)]
dem_dfp = dem_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

# %% [markdown]
# ### Dropping NaNs:

# %%
dem_clean = dem_dfp.dropna(axis = 0)
dem_clean.shape
# Out:
# (162, 9)

# %% [markdown]
# ### Building the model

# %%
X = dem_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = dem_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_dem = LR.predict(X_test)

LR_score_dem = LR.score(X_test, y_test)
PS_dem = precision_score(y_test, LR_pred_dem, average='weighted')
RS_dem = recall_score(y_test, LR_pred_dem, average='weighted')
F1_dem = f1_score(y_test, LR_pred_dem, average='weighted')

print('LR score: ', LR_score_dem)
print("precision: ", PS_dem)
print("recall: ", RS_dem)
print("f1: ", F1_dem)
# Out:
# LR score:  0.4166666666666667
# precision:  0.36874999999999997
# recall:  0.4166666666666667
# f1:  0.38125000000000003
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_dem = pd.DataFrame(LR_pred_dem).reset_index(drop = True)
result_dem = pd.concat([y_test, LR_pred_dem], axis = 1)

# %%
dem_lstc = dem_clean.columns.to_list()
dem_numc = [num for num in dem_lstc if isinstance(num, (int,float))]
dem_numc
# Out:
# [45106, 49006, 121206, 122006, 132706]

# %%
dem_num
# Out:
# [45106, 49006, 121206, 122006, 132706]

# %% [markdown]
# ## Education

# %%
education = education_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
ed_corr = education.corr()
sns.heatmap(ed_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
education.drop([23806, 23906, 24006, 24206, 103006, 176806, 177006, 
                177706, 69706, 123306], axis = 1, inplace = True)

ed_corr = education.corr()
sns.heatmap(ed_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
ed_lst = education.columns.to_list()
ed_num = [num for num in ed_lst if isinstance(num, (int,float))]
ed_df = data[data['indicator_id'].isin(ed_num)]
ed_dfp = ed_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
ed_clean = ed_dfp[(~ed_dfp['polity'].isna()) & 
                  (~ed_dfp[24106].isna()) & 
                  (~ed_dfp[63206].isna()) &
                  (~ed_dfp[63306].isna()) &
                  (~ed_dfp[46206].isna()) &
                  (~ed_dfp[133006].isna()) &
                  (~ed_dfp[46106].isna()) &
                  (~ed_dfp[123406].isna())] 

ed_clean = ed_clean.dropna(axis = 1)
ed_clean.shape
# Out:
# (101, 11)

# %%
X = ed_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = ed_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_ed = LR.predict(X_test)

LR_score_ed = LR.score(X_test, y_test)
PS_ed = precision_score(y_test, LR_pred_ed, average='weighted')
RS_ed = recall_score(y_test, LR_pred_ed, average='weighted')
F1_ed = f1_score(y_test, LR_pred_ed, average='weighted')

print('LR score: ', LR_score_ed)
print("precision: ", PS_ed)
print("recall: ", RS_ed)
print("f1: ", F1_ed)
# Out:
# LR score:  0.26666666666666666
# precision:  0.3333333333333333
# recall:  0.26666666666666666
# f1:  0.28888888888888886
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_ed = pd.DataFrame(LR_pred_ed).reset_index(drop = True)
result_ed = pd.concat([y_test, LR_pred_ed], axis = 1)
ed_lstc = ed_clean.columns.to_list()
ed_numc = [num for num in ed_lstc if isinstance(num, (int,float))]
ed_numc
# Out:
# [24106, 46106, 46206, 63206, 63306, 123406, 133006]

# %%
ed_num
# Out:
# [24106,
#  45806,
#  46106,
#  46206,
#  63206,
#  63306,
#  63406,
#  101406,
#  123406,
#  133006,
#  149206,
#  176606,
#  176906]

# %% [markdown]
# ## Environment

# %%
environment = environment_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
en_corr = environment.corr()
sns.heatmap(en_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
en_lst = environment.columns.to_list()
en_num = [num for num in en_lst if isinstance(num, (int,float))]
en_df = data[data['indicator_id'].isin(en_num)]
en_dfp = en_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

en_clean = en_dfp[(~en_dfp['polity'].isna()) &
                  (~en_dfp[174406].isna())]

en_clean = en_clean.dropna(axis = 1)
en_clean.shape
# Out:
# (158, 8)

# %%
X = en_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = en_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_en = LR.predict(X_test)

LR_score_en = LR.score(X_test, y_test)
PS_en = precision_score(y_test, LR_pred_en, average='weighted')
RS_en = recall_score(y_test, LR_pred_en, average='weighted')
F1_en = f1_score(y_test, LR_pred_en, average='weighted')

print('LR score: ', LR_score_en)
print("precision: ", PS_en)
print("recall: ", RS_en)
print("f1: ", F1_en)
# Out:
# LR score:  0.2608695652173913
# precision:  0.15579710144927536
# recall:  0.2608695652173913
# f1:  0.18115942028985507
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_en = pd.DataFrame(LR_pred_en).reset_index(drop = True)
result_en = pd.concat([y_test, LR_pred_en], axis = 1)
en_lstc = en_clean.columns.to_list()
en_numc = [num for num in en_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Gender

# %%
gender = gender_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
gen_corr = gender.corr()
sns.heatmap(gen_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
gender.drop([123606, 36806, 175606, 68606], axis = 1, inplace = True)

gen_corr = gender.corr()
sns.heatmap(gen_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
gen_lst = gender.columns.to_list()
gen_num = [num for num in gen_lst if isinstance(num, (int,float))]
gen_df = data[data['indicator_id'].isin(gen_num)]
gen_dfp = gen_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

# %%
gen_clean = gen_dfp[(~gen_dfp['polity'].isna()) & 
                    (~gen_dfp[31706].isna()) &
                    (~gen_dfp[128106].isna()) &
                    (~gen_dfp[175706].isna()) &
                    (~gen_dfp[181206].isna()) &
                    (~gen_dfp[175506].isna()) &
                    (~gen_dfp[123506].isna())] 

gen_clean = gen_clean.dropna(axis = 1)
gen_clean.shape
# Out:
# (108, 10)

# %%
X = gen_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = gen_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_gen = LR.predict(X_test)

LR_score_gen = LR.score(X_test, y_test)
PS_gen = precision_score(y_test, LR_pred_gen, average='weighted')
RS_gen = recall_score(y_test, LR_pred_gen, average='weighted')
F1_gen = f1_score(y_test, LR_pred_gen, average='weighted')

print('LR score: ', LR_score_gen)
print("precision: ", PS_gen)
print("recall: ", RS_gen)
print("f1: ", F1_gen)
# Out:
# LR score:  0.3125
# precision:  0.3125
# recall:  0.3125
# f1:  0.2976190476190476
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_gen = pd.DataFrame(LR_pred_gen).reset_index(drop = True)
result_gen = pd.concat([y_test, LR_pred_gen], axis = 1)
gen_lstc = gen_clean.columns.to_list()
gen_numc = [num for num in gen_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Health

# %%
health = health_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
hlt_corr = health.corr()
sns.heatmap(hlt_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
health.drop([57806, 57906], axis = 1, inplace = True)

hlt_corr = health.corr()
sns.heatmap(hlt_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
hlt_lst = health.columns.to_list()
hlt_num = [num for num in hlt_lst if isinstance(num, (int,float))]
hlt_df = data[data['indicator_id'].isin(hlt_num)]
hlt_dfp = hlt_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

# %%
hlt_clean = hlt_dfp[(~hlt_dfp['polity'].isna())] 
hlt_clean = hlt_clean.dropna(axis = 0)
hlt_clean.shape
# Out:
# (102, 7)

# %%
X = hlt_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = hlt_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_hlt = LR.predict(X_test)

LR_score_hlt = LR.score(X_test, y_test)
PS_hlt = precision_score(y_test, LR_pred_hlt, average='weighted')
RS_hlt = recall_score(y_test, LR_pred_hlt, average='weighted')
F1_hlt = f1_score(y_test, LR_pred_hlt, average='weighted')

print('LR score: ', LR_score_hlt)
print("precision: ", PS_hlt)
print("recall: ", RS_hlt)
print("f1: ", F1_hlt)
# Out:
# LR score:  0.06666666666666667
# precision:  0.013333333333333334
# recall:  0.06666666666666667
# f1:  0.022222222222222223
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_hlt = pd.DataFrame(LR_pred_hlt).reset_index(drop = True)
result_hlt = pd.concat([y_test, LR_pred_hlt], axis = 1)
hlt_lstc = hlt_clean.columns.to_list()
hlt_numc = [num for num in hlt_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Security

# %%
security = security_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
sec_corr = security.corr()
sns.heatmap(sec_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
sec_lst = security.columns.to_list()
sec_num = [num for num in sec_lst if isinstance(num, (int,float))]
sec_df = data[data['indicator_id'].isin(sec_num)]
sec_dfp = sec_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

# %%
sec_clean = sec_dfp[(~sec_dfp['polity'].isna()) & 
                    (~sec_dfp[128306].isna()) &
                    (~sec_dfp[61006].isna())] 

sec_clean = sec_clean.dropna(axis = 1)
sec_clean.shape
# Out:
# (149, 7)

# %%
X = sec_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = sec_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_sec = LR.predict(X_test)

LR_score_sec = LR.score(X_test, y_test)
PS_sec = precision_score(y_test, LR_pred_sec, average='weighted')
RS_sec = recall_score(y_test, LR_pred_sec, average='weighted')
F1_sec = f1_score(y_test, LR_pred_sec, average='weighted')

print('LR score: ', LR_score_sec)
print("precision: ", PS_sec)
print("recall: ", RS_sec)
print("f1: ", F1_sec)
# Out:
# LR score:  0.13636363636363635
# precision:  0.08522727272727272
# recall:  0.13636363636363635
# f1:  0.10489510489510488
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test_sec = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_sec = pd.DataFrame(LR_pred_sec).reset_index(drop = True)
result_sec = pd.concat([y_test_sec, LR_pred_sec], axis = 1)
sec_lstc = sec_clean.columns.to_list()
sec_numc = [num for num in sec_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Income

# %%
income = income_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
in_corr = income.corr()
sns.heatmap(in_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
income.drop([136706], axis = 1, inplace = True)

in_corr = income.corr()
sns.heatmap(in_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
in_lst = income.columns.to_list()
in_num = [num for num in in_lst if isinstance(num, (int,float))]
in_df = data[data['indicator_id'].isin(in_num)]
in_dfp = in_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
in_clean = in_dfp[(~in_dfp['polity'].isna())] 

in_clean = in_clean.dropna(axis = 0)
in_clean.shape
# Out:
# (143, 8)

# %%
X = in_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = in_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_in = LR.predict(X_test)

LR_score_in = LR.score(X_test, y_test)
PS_in = precision_score(y_test, LR_pred_in, average='weighted')
RS_in = recall_score(y_test, LR_pred_in, average='weighted')
F1_in = f1_score(y_test, LR_pred_in, average='weighted')

print('LR score: ', LR_score_in)
print("precision: ", PS_in)
print("recall: ", RS_in)
print("f1: ", F1_in)
# Out:
# LR score:  0.23809523809523808
# precision:  0.22116402116402115
# recall:  0.23809523809523808
# f1:  0.16955266955266954
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_in = pd.DataFrame(LR_pred_in).reset_index(drop = True)
result_in = pd.concat([y_test, LR_pred_in], axis = 1)
in_lstc = in_clean.columns.to_list()
in_numc = [num for num in in_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Inequality

# %%
inequality = inequality_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
iq_corr = inequality.corr()
sns.heatmap(iq_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
inequality.drop([135206, 67106], axis = 1, inplace = True)

iq_corr = inequality.corr()
sns.heatmap(iq_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
iq_lst = inequality.columns.to_list()
iq_num = [num for num in iq_lst if isinstance(num, (int,float))]
iq_df = data[data['indicator_id'].isin(iq_num)]
iq_dfp = iq_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

iq_clean = iq_dfp[(~iq_dfp['polity'].isna())] 

iq_clean = iq_clean.dropna(axis = 0)
iq_clean.shape
# Out:
# (132, 8)

# %%
X = iq_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = iq_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_iq = LR.predict(X_test)

LR_score_iq = LR.score(X_test, y_test)
PS_iq = precision_score(y_test, LR_pred_iq, average='weighted')
RS_iq = recall_score(y_test, LR_pred_iq, average='weighted')
F1_iq = f1_score(y_test, LR_pred_iq, average='weighted')

print('LR score: ', LR_score_iq)
print("precision: ", PS_iq)
print("recall: ", RS_iq)
print("f1: ", F1_iq)
# Out:
# LR score:  0.1
# precision:  0.1
# recall:  0.1
# f1:  0.1
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_iq = pd.DataFrame(LR_pred_iq).reset_index(drop = True)
result_iq = pd.concat([y_test, LR_pred_iq], axis = 1)
iq_lstc = iq_clean.columns.to_list()
iq_numc = [num for num in iq_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## International Organisations

# %%
int_org = int_org_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
io_corr = int_org.corr()
sns.heatmap(io_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
io_lst = int_org.columns.to_list()
io_num = [num for num in io_lst if isinstance(num, (int,float))]
io_df = data[data['indicator_id'].isin(io_num)]
io_dfp = io_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

io_clean = io_dfp[(~io_dfp['polity'].isna())] 

io_clean = io_clean.dropna(axis = 0)
io_clean.shape
# Out:
# (162, 7)

# %%
X = io_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = io_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_io = LR.predict(X_test)

LR_score_io = LR.score(X_test, y_test)
PS_io = precision_score(y_test, LR_pred_io, average='weighted')
RS_io = recall_score(y_test, LR_pred_io, average='weighted')
F1_io = f1_score(y_test, LR_pred_io, average='weighted')

print('LR score: ', LR_score_io)
print("precision: ", PS_io)
print("recall: ", RS_io)
print("f1: ", F1_io)
# Out:
# LR score:  0.2916666666666667
# precision:  0.24821428571428572
# recall:  0.2916666666666667
# f1:  0.25104895104895103
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_io = pd.DataFrame(LR_pred_io).reset_index(drop = True)
result_io = pd.concat([y_test, LR_pred_io], axis = 1)
io_lstc = io_clean.columns.to_list()
io_numc = [num for num in io_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Communication

# %%
communication = communication_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
com_corr = communication.corr()
sns.heatmap(com_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
com_lst = communication.columns.to_list()
com_num = [num for num in com_lst if isinstance(num, (int,float))]
com_df = data[data['indicator_id'].isin(com_num)]
com_dfp = com_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

com_clean = com_dfp[(~com_dfp['polity'].isna()) &
                    (~com_dfp[111106].isna()) &
                    (~com_dfp[147206].isna())] 

com_clean = com_clean.dropna(axis = 1)
com_clean.shape
# Out:
# (119, 8)

# %%
X = com_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = com_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_com = LR.predict(X_test)

LR_score_com = LR.score(X_test, y_test)
PS_com = precision_score(y_test, LR_pred_com, average='weighted')
RS_com = recall_score(y_test, LR_pred_com, average='weighted')
F1_com = f1_score(y_test, LR_pred_com, average='weighted')

print('LR score: ', LR_score_com)
print("precision: ", PS_com)
print("recall: ", RS_com)
print("f1: ", F1_com)
# Out:
# LR score:  0.2777777777777778
# precision:  0.1388888888888889
# recall:  0.2777777777777778
# f1:  0.18518518518518517
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_com = pd.DataFrame(LR_pred_com).reset_index(drop = True)
result_com = pd.concat([y_test, LR_pred_com], axis = 1)
com_lstc = com_clean.columns.to_list()
com_numc = [num for num in com_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Poverty

# %%
poverty = poverty_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
pv_corr = poverty.corr()
sns.heatmap(pv_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
poverty.drop([38406, 38606, 101006, 153706], axis = 1, inplace = True)

pv_corr = poverty.corr()
sns.heatmap(pv_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
pv_lst = poverty.columns.to_list()
pv_num = [num for num in pv_lst if isinstance(num, (int,float))]
pv_df = data[data['indicator_id'].isin(pv_num)]
pv_dfp = pv_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

pv_clean = pv_dfp[(~pv_dfp['polity'].isna())] 

pv_clean = pv_clean.dropna(axis = 0)
pv_clean.shape
# Out:
# (82, 13)

# %%
X = pv_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = pv_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_pv = LR.predict(X_test)

LR_score_pv = LR.score(X_test, y_test)
PS_pv = precision_score(y_test, LR_pred_pv, average='weighted')
RS_pv = recall_score(y_test, LR_pred_pv, average='weighted')
F1_pv = f1_score(y_test, LR_pred_pv, average='weighted')

print('LR score: ', LR_score_pv)
print("precision: ", PS_pv)
print("recall: ", RS_pv)
print("f1: ", F1_pv)
# Out:
# LR score:  0.16666666666666666
# precision:  0.09722222222222221
# recall:  0.16666666666666666
# f1:  0.12222222222222223
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_pv = pd.DataFrame(LR_pred_pv).reset_index(drop = True)
result_pv = pd.concat([y_test, LR_pred_pv], axis = 1)
pv_lstc = pv_clean.columns.to_list()
pv_numc = [num for num in pv_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Socioeconomic

# %%
socioeconomic = socioeconomic_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
se_corr = socioeconomic.corr()
sns.heatmap(se_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
se_lst = socioeconomic.columns.to_list()
se_num = [num for num in se_lst if isinstance(num, (int,float))]
se_df = data[data['indicator_id'].isin(se_num)]
se_dfp = se_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

se_clean = se_dfp[(~se_dfp['polity'].isna()) &
                  (~se_dfp[181706].isna()) &
                  (~se_dfp[170106].isna()) &
                  (~se_dfp[164406].isna()) &
                  (~se_dfp[183206].isna())] 

se_clean = se_clean.dropna(axis = 1)
se_clean.shape
# Out:
# (101, 9)

# %%
X = se_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = se_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_se = LR.predict(X_test)

LR_score_se = LR.score(X_test, y_test)
PS_se = precision_score(y_test, LR_pred_se, average='weighted')
RS_se = recall_score(y_test, LR_pred_se, average='weighted')
F1_se = f1_score(y_test, LR_pred_se, average='weighted')

print('LR score: ', LR_score_se)
print("precision: ", PS_se)
print("recall: ", RS_se)
print("f1: ", F1_se)
# Out:
# LR score:  0.3333333333333333
# precision:  0.27777777777777773
# recall:  0.3333333333333333
# f1:  0.29333333333333333
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_se = pd.DataFrame(LR_pred_se).reset_index(drop = True)
result_se = pd.concat([y_test, LR_pred_se], axis = 1)
se_lstc = se_clean.columns.to_list()
se_numc = [num for num in se_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Financial

# %%
financial = financial_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
fn_corr = financial.corr()
sns.heatmap(fn_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
fn_lst = financial.columns.to_list()
fn_num = [num for num in fn_lst if isinstance(num, (int,float))]
fn_df = data[data['indicator_id'].isin(fn_num)]
fn_dfp = fn_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

fn_clean = fn_dfp[(~fn_dfp['polity'].isna()) &
                  (~fn_dfp[53506].isna()) &
                  (~fn_dfp[133206].isna()) &
                  (~fn_dfp[52606].isna()) &
                  (~fn_dfp[111306].isna())] 

fn_clean = fn_clean.dropna(axis = 1)
fn_clean.shape
# Out:
# (142, 8)

# %%
X = fn_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = fn_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_fn = LR.predict(X_test)

LR_score_fn = LR.score(X_test, y_test)
PS_fn = precision_score(y_test, LR_pred_fn, average='weighted')
RS_fn = recall_score(y_test, LR_pred_fn, average='weighted')
F1_fn = f1_score(y_test, LR_pred_fn, average='weighted')

print('LR score: ', LR_score_fn)
print("precision: ", PS_fn)
print("recall: ", RS_fn)
print("f1: ", F1_fn)
# Out:
# LR score:  0.2857142857142857
# precision:  0.11904761904761904
# recall:  0.2857142857142857
# f1:  0.16780045351473924
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_fn = pd.DataFrame(LR_pred_fn).reset_index(drop = True)
result_fn = pd.concat([y_test, LR_pred_fn], axis = 1)
fn_lstc = fn_clean.columns.to_list()
fn_numc = [num for num in fn_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Work

# %%
work = work_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
wk_corr = work.corr()
sns.heatmap(wk_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
work.drop([148306, 150606], axis = 1, inplace = True)

wk_corr = work.corr()
sns.heatmap(wk_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
wk_lst = work.columns.to_list()
wk_num = [num for num in wk_lst if isinstance(num, (int,float))]
wk_df = data[data['indicator_id'].isin(wk_num)]
wk_dfp = wk_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()

wk_clean = wk_dfp[(~wk_dfp['polity'].isna()) &
                  (~wk_dfp[123806].isna())]


wk_clean = wk_clean.dropna(axis = 1)
wk_clean.shape
# Out:
# (149, 12)

# %%
X = wk_clean.drop(['polity', 'country_name', 'region'],axis=1)
y = wk_clean['polity']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.145, 
                                                    random_state = 100)
numericals_train = X_train.select_dtypes(np.number)
numericals_test = X_test.select_dtypes(np.number)

categoricals_train = X_train.select_dtypes(object)
categoricals_test = X_test.select_dtypes(object)

transformer = StandardScaler().fit(numericals_train)
numericals_train_standardized = transformer.transform(numericals_train)
numericals_test_standardized = transformer.transform(numericals_test)

encoder = OneHotEncoder(handle_unknown='error', drop='first').fit(categoricals_train)
categoricals_train_encoded = encoder.transform(categoricals_train).toarray()
categoricals_test_encoded = encoder.transform(categoricals_test).toarray()

X_train = np.concatenate((numericals_train_standardized,categoricals_train_encoded),axis=1)
X_test = np.concatenate((numericals_test_standardized,categoricals_test_encoded),axis=1)

LR = LogisticRegression(random_state=42, solver='saga', max_iter = 10000)
LR.fit(X_train, y_train)

LR_pred_wk = LR.predict(X_test)

LR_score_wk = LR.score(X_test, y_test)
PS_wk = precision_score(y_test, LR_pred_wk, average='weighted')
RS_wk = recall_score(y_test, LR_pred_wk, average='weighted')
F1_wk = f1_score(y_test, LR_pred_wk, average='weighted')

print('LR score: ', LR_score_wk)
print("precision: ", PS_wk)
print("recall: ", RS_wk)
print("f1: ", F1_wk)
# Out:
# LR score:  0.2727272727272727
# precision:  0.18939393939393936
# recall:  0.2727272727272727
# f1:  0.20664335664335665
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\herat\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test = pd.DataFrame(y_test).reset_index(drop = True)
LR_pred_wk = pd.DataFrame(LR_pred_wk).reset_index(drop = True)
result_wk = pd.concat([y_test, LR_pred_wk], axis = 1)
wk_lstc = wk_clean.columns.to_list()
wk_numc = [num for num in wk_lstc if isinstance(num, (int,float))]

# %% [markdown]
# ## Other

# %%
other = other_df.pivot(index = ['country_name', 'continent', 'region', 'polity'], 
                                    columns= ['indicator_id'], values = 'value').reset_index().copy()
oth_corr = other.corr()
sns.heatmap(oth_corr, annot=True)
plt.rcParams["figure.figsize"] = (8,10)
plt.show()

# %%
other_df['indicator_name'].unique()
# Out:
# array(['Internet users, total (% of population)',
#        'Mortality rate, infant (per 1,000 live births)',
#        'Mortality rate, under-five (per 1,000 live births)',
#        'Infants lacking immunization, measles (% of one-year-olds)',
#        'Infants lacking immunization, DPT (% of one-year-olds)',
#        'Inequality-adjusted education index',
#        'Inequality-adjusted life expectancy index',
#        'Inequality-adjusted income index',
#        'Overall loss in HDI due to inequality (%)',
#        'Maternal mortality ratio (deaths per 100,000 live births)',
#        'Life expectancy index', 'Income index', 'Education index',
#        'Life expectancy at birth, female (years)',
#        'Life expectancy at birth, male (years)',
#        'Coefficient of human inequality',
#        'Human Development Index (HDI), female',
#        'Human Development Index (HDI), male',
#        'Human Development Index (HDI)', 'Gender Development Index (GDI)',
#        'Inequality-adjusted HDI (IHDI)', 'HDI rank',
#        'Homeless people due to natural disaster (average annual per million people)',
#        'Renewable energy consumption (% of total final energy consumption)',
#        'Forest area, change (%)',
#        'Total unemployment rate (female to male ratio)',
#        'Youth unemployment rate (female to male ratio)',
#        'Share of employment in nonagriculture, female (% of total employment in nonagriculture)',
#        'Population using improved drinking-water sources (%)',
#        'Population using improved sanitation facilities (%)',
#        'Current health expenditure (% of GDP)',
#        'Malaria incidence (per 1,000 people at risk)',
#        'Tuberculosis incidence (per 100,000 people)'], dtype=object)

# %%
other_df.pivot_table(index = 'indicator_name')
# Out:
#                                                        autoc     democ  \
# indicator_name
# Coefficient of human inequality                     0.792857  5.828571
# Current health expenditure (% of GDP)               1.215190  5.544304
# Education index                                     1.293750  5.481250
# Forest area, change (%)                             1.320755  5.433962
# Gender Development Index (GDI)                      1.193333  5.606667
# HDI rank                                            1.293750  5.481250
# Homeless people due to natural disaster (averag...  1.285714  5.478261
# Human Development Index (HDI)                       1.293750  5.481250
# Human Development Index (HDI), female               1.193333  5.606667
# Human Development Index (HDI), male                 1.193333  5.606667
# Income index                                        1.293750  5.481250
# Inequality-adjusted HDI (IHDI)                      0.792857  5.828571
# Inequality-adjusted education index                 1.086667  5.633333
# Inequality-adjusted income index                    0.787234  5.858156
# Inequality-adjusted life expectancy index           1.339506  5.444444
# Infants lacking immunization, DPT (% of one-yea...  1.339506  5.444444
# Infants lacking immunization, measles (% of one...  1.339506  5.444444
# Internet users, total (% of population)             1.285714  5.478261
# Life expectancy at birth, female (years)            1.339506  5.444444
# Life expectancy at birth, male (years)              1.339506  5.444444
# Life expectancy index                               1.339506  5.444444
# Malaria incidence (per 1,000 people at risk)        1.925532  4.904255
# Maternal mortality ratio (deaths per 100,000 li...  1.339506  5.444444
# Mortality rate, infant (per 1,000 live births)      1.339506  5.444444
# Mortality rate, under-five (per 1,000 live births)  1.339506  5.444444
# Overall loss in HDI due to inequality (%)           0.792857  5.828571
# Population using improved drinking-water source...  1.291925  5.478261
# Population using improved sanitation facilities...  1.339506  5.444444
# Renewable energy consumption (% of total final ...  1.339506  5.444444
# Share of employment in nonagriculture, female (...  1.339506  5.444444
# Total unemployment rate (female to male ratio)      1.339506  5.444444
# Tuberculosis incidence (per 100,000 people)         1.339506  5.444444
# Youth unemployment rate (female to male ratio)      1.339506  5.444444
#
#                                                     indicator_id    polity  \
# indicator_name
# Coefficient of human inequality                           135006  4.564286
# Current health expenditure (% of GDP)                     181806  3.911392
# Education index                                           103706  3.775000
# Forest area, change (%)                                   164206  3.698113
# Gender Development Index (GDI)                            137906  3.973333
# HDI rank                                                  146206  3.775000
# Homeless people due to natural disaster (averag...        149406  3.782609
# Human Development Index (HDI)                             137506  3.775000
# Human Development Index (HDI), female                     136906  3.973333
# Human Development Index (HDI), male                       137006  3.973333
# Income index                                              103606  3.775000
# Inequality-adjusted HDI (IHDI)                            138806  4.564286
# Inequality-adjusted education index                        71406  4.106667
# Inequality-adjusted income index                           71606  4.602837
# Inequality-adjusted life expectancy index                  71506  3.697531
# Infants lacking immunization, DPT (% of one-yea...         64406  3.697531
# Infants lacking immunization, measles (% of one...         64306  3.697531
# Internet users, total (% of population)                    43606  3.782609
# Life expectancy at birth, female (years)                  120606  3.697531
# Life expectancy at birth, male (years)                    121106  3.697531
# Life expectancy index                                     103206  3.697531
# Malaria incidence (per 1,000 people at risk)              182106  2.978723
# Maternal mortality ratio (deaths per 100,000 li...         89006  3.697531
# Mortality rate, infant (per 1,000 live births)             57206  3.697531
# Mortality rate, under-five (per 1,000 live births)         57506  3.697531
# Overall loss in HDI due to inequality (%)                  73506  4.564286
# Population using improved drinking-water source...        177106  3.776398
# Population using improved sanitation facilities...        177206  3.697531
# Renewable energy consumption (% of total final ...        163906  3.697531
# Share of employment in nonagriculture, female (...        175106  3.697531
# Total unemployment rate (female to male ratio)            169706  3.697531
# Tuberculosis incidence (per 100,000 people)               182206  3.697531
# Youth unemployment rate (female to male ratio)            169806  3.697531
#
#                                                          value
# indicator_name
# Coefficient of human inequality                      19.432000
# Current health expenditure (% of GDP)                 6.811892
# Education index                                       0.655188
# Forest area, change (%)                               2.884783
# Gender Development Index (GDI)                        0.940807
# HDI rank                                             93.827957
# Homeless people due to natural disaster (averag...  191.005405
# Human Development Index (HDI)                         0.712446
# Human Development Index (HDI), female                 0.696137
# Human Development Index (HDI), male                   0.734124
# Income index                                          0.696011
# Inequality-adjusted HDI (IHDI)                        0.580520
# Inequality-adjusted education index                   0.557066
# Inequality-adjusted income index                      0.528987
# Inequality-adjusted life expectancy index             0.692440
# Infants lacking immunization, DPT (% of one-yea...    6.947368
# Infants lacking immunization, measles (% of one...   12.436842
# Internet users, total (% of population)              50.171658
# Life expectancy at birth, female (years)             74.486264
# Life expectancy at birth, male (years)               69.617582
# Life expectancy index                                 0.802947
# Malaria incidence (per 1,000 people at risk)         88.364948
# Maternal mortality ratio (deaths per 100,000 li...  165.782123
# Mortality rate, infant (per 1,000 live births)       22.583684
# Mortality rate, under-five (per 1,000 live births)   29.982632
# Overall loss in HDI due to inequality (%)            19.839333
# Population using improved drinking-water source...   86.525263
# Population using improved sanitation facilities...   74.227368
# Renewable energy consumption (% of total final ...   31.903158
# Share of employment in nonagriculture, female (...   39.901695
# Total unemployment rate (female to male ratio)        1.383729
# Tuberculosis incidence (per 100,000 people)         114.501571
# Youth unemployment rate (female to male ratio)        1.093898
